# %% [markdown]
# <a href="https://colab.research.google.com/github/profjocile/Exercicios-no-colab/blob/main/exercicios2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercicos condicionais
#
# Faça um algoritmo para ler dois números e imprimir o maior, o menor ou então dizer se são iguais.
#
# Algoritmo:
#
# 1. Leia o primeiro número e salve na variável num1
# 2. Leia o segundo número e salve na variável num2
# 3. Descobrir o maior
# 4. Mostrar o maior
# 5. Descobrir o menor
# 6. Mostrar o menor
# 7. Descobir se são iguais
# 8. Mostrar se são iguais

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
if num1 > num2:
    print(f"O maior número é {num1}")
    print(f"O menor número é {num2}")
elif num1 < num2:
    print(f"O maior número é {num2}")
    print(f"O menor número é {num1}")
else:
    print("Os números são iguais")
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 4
# O maior número é 5.0
# O menor número é 4.0

# %% [markdown]
# 4. Faça um algoritmo para ler um número inteiro e dizer se o número lido é par ou impar.
#
# Algoritmo:
#
# 1. Leia o primeiro número e salve na variável num
# 2. Descobrir se é par ou impar: dividindo por 2 e se tiver resto o número é ímpar.
# 3. Mostrar o resultado.

# %%
num = int(input("Digite um número: "))
if num % 2 == 0:
    print(f"O número {num} é par")
else:
    print(f"O número {num} é ímpar")
# Out:
# Digite um número: 5
# O número 5 é ímpar

# %% [markdown]
# 5. Faça um algoritmo para ler dois números A e B e dizer se A é divisível por B.
#
# Algoritmo:
#
# 1. Leia o primeiro número e salve em uma variável num1
# 2. Leia o segundo número e salve em uma variável num2
# 3. Verifique se num1 é divisível pelo num2:
#   - se o resto for maior que zero mostre que é divisível
#   - senão mostre que não é divisível

# %%
num1 = int(input("Digite o primeiro número: "))
num2 = int(input("Digite o segundo número: "))
if num1 % num2 == 0:
    print(f"{num1} é divisível por {num2}")
else:
    print(f"{num1} não é divisível por {num2}")
# Out:
# Digite o primeiro número: 4
# Digite o segundo número: 2
# 4 é divisível por 2

# %% [markdown]
# 6. Faça um algoritmo para ler dois números e imprimi-los em ordem crescente.
#
# Algoritmo:
#
# 1. Leia o primeiro número e salve na variável num1
# 2. Leia o segundo número e salve na variável num2
# 3. Descobrir o menor
# 4. Mostrar o menor número
# 5. mostrar o maior em seguida

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
if num1 < num2:
    print(f"{num1}, {num2}")
else:
    print(f"{num2}, {num1}")
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 5
# 5.0, 5.0
